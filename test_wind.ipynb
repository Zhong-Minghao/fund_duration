# %%
import pandas as pd
from WindPy import w
w.start()
# Out:
# .ErrorCode=0
# .Data=[Already connected!]

# %%
data = w.wss("000015.OF", "risk_duration","rptDate=20251231")
data
# Out:
# .ErrorCode=0
# .Codes=[000015.OF]
# .Fields=[RISK_DURATION]
# .Times=[20260628 17:31:15]
# .Data=[[7.093250275664662]]

# %%
data = w.wsd("000015.OF", "nav", '2025-12-30', '2026-03-01', "PriceAdj=B")
df = pd.DataFrame({'nav': data.Data[0]}, index=data.Times)
df
# Out:
#                nav
# 2025-12-30  1.1801
# 2025-12-31  1.1804
# 2026-01-05  1.1809
# 2026-01-06  1.1803
# 2026-01-07  1.1800
# 2026-01-08  1.1805
# 2026-01-09  1.1808
# 2026-01-12  1.1813
# 2026-01-13  1.1816
# 2026-01-14  1.1818
# 2026-01-15  1.1819
# 2026-01-16  1.1825
# 2026-01-19  1.1826
# 2026-01-20  1.1830
# 2026-01-21  1.1833
# 2026-01-22  1.1834
# 2026-01-23  1.1838
# 2026-01-26  1.1840
# 2026-01-27  1.1839
# 2026-01-28  1.1840
# 2026-01-29  1.1841
# 2026-01-30  1.1841
# 2026-02-02  1.1841
# 2026-02-03  1.1840
# 2026-02-04  1.1840
# 2026-02-05  1.1843
# 2026-02-06  1.1848
# 2026-02-09  1.1853
# 2026-02-10  1.1854
# 2026-02-11  1.1858
# 2026-02-12  1.1861
# 2026-02-13  1.1861
# 2026-02-24  1.1867
# 2026-02-25  1.1863
# 2026-02-26  1.1857
# 2026-02-27  1.1860
